# %% [markdown]
# "Oops" stands for Object-Oriented Programming System

# %%
a= 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type("pwskills"))
# Out:
# <class 'str'>

# %%
class test:
    pass

# %%
class Mayya:
    pass

# %%
m = Mayya()

# %%
m

# %%
m.__dict__
# Out:
# {}

# %%
m.__doc__

# %%
m.__module__
# Out:
# '__main__'

# %%
type(m)
# Out:
# __main__.Mayya

# %%
a = test()

# %%
print(type(a))
# Out:
# <class '__main__.test'>

# %%
class pwskills:
    
    def welcome_msg(self):
        print("welcome to pwskills")

# %%
rohan = pwskills()

# %%
rohan.__dict__
# Out:
# {}

# %%
rohan.__doc__

# %%
rohan.__module__
# Out:
# '__main__'

# %%
rohan.welcome_msg()
# Out:
# welcome to pwskills

# %%
sohan = pwskills()

# %%
sohan.welcome_msg()
# Out:
# welcome to pwskills

# %%
class PW:
    def GreetMsg(self):
        print("Welcome Sodhara")

# %%
pw = PW()

# %%
pw.GreetMsg
# Out:
# <bound method PW.GreetMsg of <__main__.PW object at 0x7b0421f0d950>>

# %%
pw.GreetMsg()
# Out:
# Welcome Sodhara

# %%
a = 1

# %%
b = 2

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
class pwskills1:
    
    def __init__(self ,phone_number , email_id, student_id ):
        
        self.phone_number = phone_number
        self.email_id = email_id
        self.student_id = student_id
        
    
    def return_student_detials(self):
        return self.phone_number, self.email_id , self.student_id

# %%
sohan = pwskills1(999679869 , "sohan@gmail.com" , 102)

# %%
sohan.phone_number
# Out:
# 999679869

# %%
sohan.return_student_detials()
# Out:
# (999679869, 'sohan@gmail.com', 102)

# %%
class PWSkills:
    def __init__(self,name,phone_number):
        self.phone_number = phone_number
        self.name = name
    def GetStuff(self):
        return self.name, self.phone_number

# %%
pw = PWSkills(12345,'SaiKiranPatnana')

# %%
pw.name
# Out:
# 12345

# %%
pw.phone_number
# Out:
# 'SaiKiranPatnana'

# %%
pw.GetStuff()
# Out:
# (12345, 'SaiKiranPatnana')

# %%
rohan = pwskills1(95435665, "rohan@gmail.com" , 101)

# %%
rohan.phone_number
# Out:
# 95435665

# %%
rohan.email_id
# Out:
# 'rohan@gmail.com'

# %%
rohan.student_id
# Out:
# 101

# %%
rohan.return_student_detials()
# Out:
# (95435665, 'rohan@gmail.com', 101)

# %%
class pwskills2:
    
    def __init__(sudh ,phone_number , email_id, student_id ):
        
        sudh.phone_number = phone_number
        sudh.email_id = email_id
        sudh.student_id = student_id
        
    
    def return_student_detials(sudh):
        return sudh.phone_number, sudh.email_id , sudh.student_id

# %%
mohan = pwskills2(99699579567, "mohan@gmail.com" , 234)

# %%
mohan.phone_number
# Out:
# 99699579567

# %%
mohan.return_student_detials()
# Out:
# (99699579567, 'mohan@gmail.com', 234)

# %%
class pwskills3:
    
    def __init__(sudh ,phone_number , email_id, student_id ):
        
        sudh.phone_number1 = phone_number
        sudh.email_id = email_id
        sudh.student_id = student_id
        
    
    def return_student_detials(sudh):
        return sudh.phone_number1, sudh.email_id , sudh.student_id

# %%
rohan = pwskills3(999735,"rohan@gmail.com" , 123)

# %%
rohan.phone_number1
# Out:
# 999735

# %%
rohan.return_student_detials()
# Out:
# (999735, 'rohan@gmail.com', 123)

# %%
class Sai:
    def __init__(sai, name, id):
        sai.name = name
        sai.id = id
    def GetDetails(sai):
        return sai.name, sai.id

# %%
sai = Sai('Sai',143)

# %%
sai.GetDetails()
# Out:
# ('Sai', 143)

# %%
sai.name
# Out:
# 'Sai'

# %%
sai.id
# Out:
# 143

# %%
class SaiKiran:
    def __init__(self, name, id):
        self.name = name
        self.id = id
    def display(self):
        return self.name, self.id;

# %%
saikiran = SaiKiran('SaiKiran',143)

# %%
saikiran.id
# Out:
# 143

# %%
saikiran.name
# Out:
# 'SaiKiran'

# %%
saikiran.display()
# Out:
# ('SaiKiran', 143)

# %%
class SaiKiran:
    def __init__(sai):
        pass
    def display(sai,name,id):
        return name, id

# %%
saikiran = SaiKiran()

# %%
saikiran.display("Sai", 143)
# Out:
# ('Sai', 143)

# %%
type(saikiran)
# Out:
# __main__.SaiKiran

# %%
a = 1
type(a)
# Out:
# int

# %%
print(type(a))
# Out:
# <class 'int'>
