# %%
#use always a specific exception
try :
    10/0
except Exception as e :
    print(e)
# Out:
# division by zero

# %%
try :
    10/0
except ZeroDivisionError as e :
    print(e)
# Out:
# division by zero

# %%
try:
    print(10/0)
except ZeroDivisionError as e:
    print('Hey Prasanna, Zero Division has taken place ra..!')
# Out:
# Hey Prasanna, Zero Division has taken place ra..!

# %%
#print always a valid msg
try :
    10/0
except ZeroDivisionError as e :
    print("this is my zero dedision error i am handling " , e)
# Out:
# this is my zero dedision error i am handling  division by zero

# %%
#always try to log 
import logging
logging.basicConfig(filename = "error.log" , level = logging.ERROR)
try :
    10/0
except ZeroDivisionError as e :
    logging.error("this is my zero dedision error i am handling {} ".format( e))

# %%
import logging
logging.basicConfig(filename = 'pra.log', level = logging.error, format = '%(asctime)s %(message)s %(filename)s %(name)s')

# %%
#always avoid to write a multiple exception handling 
try :
    10/0
except FileNotFoundError as e : 
    logging.error("this is my file not found  {} ".format( e))
except AttributeError as e : 
    logging.error("this is my attribute error  {} ".format( e))
except ZeroDivisionError as e :
    logging.error("this is my zero dedision error i am handling {} ".format( e))

# %%
try:
    print(10/0)
    f = open('pra.csv', r)
except ZeroDivisionError as e:
    print('This is zero division error!')
    logging.error('This is zero division error {}!'.format(e))
except FileNotFoundError as e:
    print('This is file not found error!')
    logging.error('This is file not found error {}!'.format(e))
except Exception as e:
    logging.error(e)
    print(e)
finally:
    print('I Love You Till To My Last Breathe Prasanna!')
    f.close()
# Out:
# This is zero division error!
# I Love You Till To My Last Breathe Prasanna!

# %%
#prepare a proper documnetation

# %%
#cleanup all the resources 
try :
    with open("test.txt" , "w" ) as f :
        f.write("thsi is my msg to file " )
except FileNotFoundError as e : 
     logging.error("this is my file not found  {} ".format( e))
finally : 
    f.close()
