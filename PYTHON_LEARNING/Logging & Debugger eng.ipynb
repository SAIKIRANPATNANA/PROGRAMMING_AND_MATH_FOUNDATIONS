# %%
print("this is my print stamt")
# Out:
# this is my print stamt

# %%
import logging

# %%
logging.basicConfig(filename = "test.log" , level = logging.INFO)

# %%
logging.basicConfig(filename = 'pra.log', level = logging.INFO)

# %%
logging.info('This is my info')

# %%
logging.error('This is my error')

# %%
logging.critical('This is my critical')

# %%
logging.warning('This is my warning')

# %%
logging.debug('This is my debug')

# %%
logging.info("this is my line of execution ")

# %%
logging.error("this is my error")

# %%
logging.critical("this is my critical")

# %%
logging.warning("this is my warning ")

# %%
logging.debug("this is my info related to debug")

# %%
# logging.noset("this is my noset related log")

# %%
logging.shutdown()

# %%
logging.info('This is my info')

# %%
logging.shutdown()

# %% [markdown]
# 1. NOSET
# 2. DEBUG
# 3. INFO
# 4. WARNING
# 5. ERROR
# 6. CRITICAL

# %%
logging.basicConfig(filename = "test1.log" , level = logging.DEBUG ,format = '%(asctime)s %(message)s'  )

# %%
logging.basicConfig(filename = 'test.log', level = logging.debug, format = '%(asctime)s %(message)s %(levelname)s %(name)')

# %%
logging.info("this is my info log")

# %%
logging.info('This is my info')

# %%
logging.warning('This is my warning')

# %%
logging.error('This is my error')

# %%
logging.debug('This is my debug')

# %%
logging.critical('This is my critical')

# %%
logging.debug("this is my debug log")

# %%
logging.warning("this is my warning ")

# %%
logging.shutdown()

# %%
logging.basicConfig(filename = "test3.log" , level = logging.DEBUG, format = '%(asctime)s %(name)s %(levelname)s  %(message)s')

# %%
logging.info("this is my info log")

# %%
l = [1,2,3,4,[4,5,6] , "sudh" ,"kumar"]

# %%
LoveWithPrasanna = ['Fallen for her at first sight', 'Got mad about later', 'Wanted to chat with her till late nights', 'Want to impress her whereever there is scope', 'Started loving her like anything else', 'After knowing there is tough competition for me' , 'Decided to leave her' , 'Felt the pain like being in the hell','Gradually started deleting her moment from the mind', 'Despite all thee,She is my Goddess']

# %%
l1_int = []
l2_str = []
for i in l : 
    logging.info("this is the start of my first for loop {}".format(l))
    logging.info("this is the value of i am logging {}".format(i))
    if type(i) == list:
        for j in i :
            logging.info("logggin my j {j} and i is {i}".format(i = i ,j = j))
            if type(j) == int :
                l1_int.append(j)
    elif type(i) == int :
        l1_int.append(i)
        
    else :
        if type(i) == str:
            l2_str.append(i)
logging.info("this is my final result  with all int {l1} ,with all str{l2}".format(l1 =l1_int ,l2 =l2_str ))

# %%
l1_int
# Out:
# [1, 2, 3, 4, 4, 5, 6]

# %%
l2_str
# Out:
# ['sudh', 'kumar']

# %%
import io

# %%
logging.info('My Love Journey has Started With My So Called Goddess.. Prasanna!')
with open('LoveWithPrasanna.txt', 'a') as f:
    for stuff in LoveWithPrasanna:
        f.writelines(stuff)
        logging.critical(stuff)
    f.write('Always Cherish You Prasanna..! Love You My Goddess!')
    f.flush()
logging.info('My Love Journey has been ended with My So Called Goddess.. Prasanna!')
logging.critical('Always Cherish You Prasanna..! Love You My Goddess!')

# %%
f = open('LoveWithPrasanna.txt','r')

# %%
data = f.read()

# %%
data
# Out:
# 'Fallen for her at first sightGot mad about laterWanted to chat with her till late nightsWant to impress her whereever there is scopeStarted loving her like anything elseAfter knowing there is tough competition for meDecided to leave herFelt the pain like being in the hellGradually started deleting her moment from the mindDespite all thee,She is my GoddessAlways Cherish You Prasanna..! Love You My Goddess!'

# %%
data1 = f.read()

# %%
data1
# Out:
# ' her at first sightGot mad about laterWanted to chat with her till late nightsWant to impress her whereever there is scopeStarted loving her like anything elseAfter knowing there is tough competition for meDecided to leave herFelt the pain like being in the hellGradually started deleting her moment from the mindDespite all thee,She is my GoddessAlways Cherish You Prasanna..! Love You My Goddess!'

# %%
f.seek(10)
# Out:
# 10

# %%
import shutil

# %%
shutil.copy('LoveWithPrasanna.txt', 'LoveYouPrasanna.txt')
# Out:
# 'LoveYouPrasanna.txt'

# %%
f = open('LoveWithPrasanna.txt', 'r')

# %%
f.read()
# Out:
# 'Fallen for her at first sightGot mad about laterWanted to chat with her till late nightsWant to impress her whereever there is scopeStarted loving her like anything elseAfter knowing there is tough competition for meDecided to leave herFelt the pain like being in the hellGradually started deleting her moment from the mindDespite all thee,She is my GoddessAlways Cherish You Prasanna..! Love You My Goddess!'

# %%
f.read()
# Out:
# ''

# %%
import os

# %%
os.remove('LoveWithPrasanna.txt')

# %%
os.path.getsize('LoveYouPrasanna.txt')
# Out:
# 408
