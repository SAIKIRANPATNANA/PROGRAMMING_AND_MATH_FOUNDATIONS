# %%
#str methods: endswith, startswith, join, reverse, isupper, islower, isalnum, upper, len, lower,  isalpha, isspace, isdigit, strip-lr, 
#list methods: pop, remove, apend, extend, sort, reverse, join, index, min, max, len, copy
# tuple methods: count, index, min, max, len,
#dict methonds: update, fromkeys, pop, get, copy, keys, values, items, popitem, fromkeys,clear
#str value @ a idx is not modifiable
#tuple value @ a idx is not modiafiable (i.e immutable)
#set allows str and tuple to be part of it's emements (i.e immutable)
#set does not allow indexing and range accessing
#set methods: clear, copy, add, difference, intersection, union, issubset, issuperset, isdisjoint, symmetric_difference, pop, remove, update

# %%
s = {1,2,3,4}

# %%
s.add(5)

# %%
s.symmetric_diff
# Out:
# {1, 2, 3, 4, 5}

# %%
s.difference({1})
# Out:
# {2, 3, 4, 5}

# %%
s.pop()
# Out:
# 1

# %%
s.remove(2)

# %%
s
# Out:
# {3, 4, 5}

# %%
s.update({1,2})

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s1 = {1,2,3,4,5}

# %%
type(s1)
# Out:
# set

# %%
s2 = {1,1,12,3,3,3,4,5,5,5,55,523,34,3,45,6,67}

# %%
s2
# Out:
# {1, 3, 4, 5, 6, 12, 34, 45, 55, 67, 523}

# %%
l = list(s2)

# %%
tuple(s2)
# Out:
# (1, 34, 3, 4, 5, 6, 67, 523, 12, 45, 55)

# %%
l
# Out:
# [1, 34, 3, 4, 5, 6, 67, 523, 12, 45, 55]

# %%
set(l)
# Out:
# {1, 3, 4, 5, 6, 12, 34, 45, 55, 67, 523}

# %%
s4 = {1,2,3,4,[1,2,3,4]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s4 = {1,2,3,4,[1,2,3,4]}
#
# TypeError: unhashable type: 'list'

# %%
s5 = {1,2,3,4, (1,2,3,4)}

# %%
s5
# Out:
# {(1, 2, 3, 4), 1, 2, 3, 4}

# %%
s1 = {1,2,3} 
s2 = {3,4,5}

# %%
s1.intersection(s2)
# Out:
# {3}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 4, 5}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.issubset(s2)
# Out:
# False

# %%
s1.issuperset(s2)
# Out:
# False

# %%
s6 = {"sudh" , "Sudh" , 2,3,4,5}

# %%
s6
# Out:
# {2, 3, 4, 5, 'Sudh', 'sudh'}

# %%
s7  = {"sudh" , "sudh" , 2,3,4,5}

# %%
s7
# Out:
# {2, 3, 4, 5, 'sudh'}

# %%
s7
# Out:
# {2, 3, 4, 5, 'sudh'}

# %%
s7[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 s7[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s7[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 s7[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
s7
# Out:
# {2, 3, 4, 5, 'sudh'}

# %%
for i in s7 :
    print(i)
# Out:
# 2
# 3
# 4
# 5
# sudh

# %%
s7
# Out:
# {2, 3, 4, 5, 'sudh'}

# %%
s7.add(34)

# %%
s7
# Out:
# {2, 3, 34, 4, 5, 'sudh'}

# %%
s7.add(2)

# %%
s7
# Out:
# {2, 3, 34, 4, 5, 'sudh'}

# %%
len(s7)
# Out:
# 6

# %%
s7.pop()
# Out:
# 2

# %%
s7
# Out:
# {3, 34, 4, 5, 'sudh'}

# %%
s7.pop()
# Out:
# 3

# %%
s7.pop()
# Out:
# 4

# %%
s7.pop()
# Out:
# 5

# %%
s7
# Out:
# {34, 'sudh'}

# %%
s7
# Out:
# {34, 'sudh'}

# %%
s7.clear()

# %%
s7
# Out:
# set()

# %%
s8 = {1,2,3,4}
s9 = {1,2,3,5}

# %%
s8.difference(s9)
# Out:
# {4}

# %%
s9.difference(s8)
# Out:
# {5}

# %%
s11 = {}

# %%
type(s11)
# Out:
# dict

# %%
s11  = {1,2,3,4}

# %%
type(s11)
# Out:
# set

# %%
s11.add(5)

# %%
s11
# Out:
# {1, 2, 3, 4, 5}

# %%
s11.difference({1,2,3,4})
# Out:
# {5}

# %%
s11.intersection({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
s11.union({1,2,3,4,6})
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s11.symmetric_difference({1,2,3,4,6})
# Out:
# {5, 6}

# %%
for i in range(len(s11)):
    print(s11[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 for i in range(len(s11)):
# ----> 2     print(s11[i])
#
# TypeError: 'set' object is not subscriptable

# %%
for ele in s11:
    print(ele)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
s11[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 s11[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s11[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 s11[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
s11.add(6)

# %%
s11
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#Set is immutable, accessble using index becoz set is a well defined collection of dist elements;
