# %%
import pymongo
# client = pymongo.MongoClient("mongodb+srv://pwskills:pwskills@cluster0.yrgsdmj.mongodb.net/?retryWrites=true&w=majority")
# client = pymongo.MongoClient("mongodb+srv://saikiranpatnana:mayya143@saikiran.bdu0jbl.mongodb.net/?retryWrites=true&w=majority&appName=saikiran")
# db = client.test
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://saikiranpatnana:mayya143@saikiran.bdu0jbl.mongodb.net/?retryWrites=true&w=majority&appName=saikiran"
# Create a new client and connect to the server
client = MongoClient(uri)
# db = client.NikhilMalayakkal
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import pymongo 
from pymongo.mongo_client import MongoClient
uri = "mongodb+srv://saikiranpatnana:mayya143@saikiran.bdu0jbl.mongodb.net/?retryWrites=true&w=majority&appName=saikiran"
client = MongoClient(uri)
db = client.NikhilMalayakkal

# %%
# pip install pymongo

# %%
coll_create = db['Nikhil Anna']

# %%
collection = db['Nikhil Anna']

# %%
data = {"name" : "sudh",
        "class" : "data science masters ",
        "timing " : "flexi"
       }

# %%
coll_create.insert_one(data)
# Out:
# InsertOneResult(ObjectId('675b2c0ed4f040202bc71e4e'), acknowledged=True)

# %%
data1 = {"mail_id" : "sudh@gmail.com",
         "phone_number" :2343243242
}

# %%
data = {'Winner': 'Nikhil', 'Runner': 'Gowtham'}

# %%
data.find(

# %%
coll_create.insert_one(data1)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 coll_create.insert_one(data1)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# ...

# %%
collection.insert_one(data)
# Out:
# InsertOneResult(ObjectId('675b2c02d4f040202bc71e4c'), acknowledged=True)

# %%
data2 = {"list_course" : ["data science masters " , "web dev " , "java with DSA"],
        "mentor" : ["sudhanshu" , "anurag" , "hyder"]}

# %%
collection.insert_one(data2)
# Out:
# InsertOneResult(ObjectId('675b2c03d4f040202bc71e4d'), acknowledged=True)

# %%
coll_create.insert_one(data2)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 coll_create.insert_one(data2)
#
# File ~/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
#     677     ),
#     678     write_concern.acknowledged,
#     679 )
#
# ...

# %%
 data3 = [
  { "name": "Amy", "address": "Apple st 652" },
  { "name": "Hannah", "address": "Mountain 21" },
  { "name": "Michael", "address": "Valley 345" },
  { "name": "Sandy", "address": "Ocean blvd 2" },
  { "name": "Betty", "address": "Green Grass 1" },
  { "name": "Richard", "address": "Sky st 331" },
  { "name": "Susan", "address": "One way 98" },
  { "name": "Vicky", "address": "Yellow Garden 2" },
  { "name": "Ben", "address": "Park Lane 38" },
  { "name": "William", "address": "Central st 954" },
  { "name": "Chuck", "address": "Main Road 989" },
  { "name": "Viola", "address": "Sideway 1633" }
]

# %%
coll_create.insert_many(data3)

# %%
collection.insert_many(data3)

# %%
data4 = {
 "name": "notebook",
 "qty": 50,
 "rating": [ { "score": 8 }, { "score": 9 } ],
 "size": { "height": 11, "width": 8.5, "unit": "in" },
 "status": "A",
 "tags": [ "college-ruled", "perforated"]
}

# %%
data5 = [{'Winner': 'NikhilMalayakkal'},{'Runner':'Gowtham'}]

# %%
coll_create.insert_one(data4)

# %%
collection.insert_many(data5)

# %%
list_of_records = [
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'iNeuron',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'iNeuron',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

# %%
coll_create.insert_many(list_of_records)

# %%
collection.insert_many(list_of_records)
# Out:
# InsertManyResult([ObjectId('6751c89912e4855fc2e177ec'), ObjectId('6751c89912e4855fc2e177ed'), ObjectId('6751c89912e4855fc2e177ee')], acknowledged=True)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('6751c86712e4855fc2e177e6'), 'name': 'sudh', 'class': 'data science masters ', 'timing ': 'flexi'}
# {'_id': ObjectId('6751c87012e4855fc2e177e7'), 'Winner': 'Nikhil', 'Runner': 'Gowtham'}
# {'_id': ObjectId('6751c87812e4855fc2e177e8'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('6751c88212e4855fc2e177e9'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('6751c56412e4855fc2e177d3'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6751c56412e4855fc2e177d4'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6751c56412e4855fc2e177d5'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6751c56412e4855fc2e177d6'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6751c56412e4855fc2e177d7'), 'name': 'Betty', 'address': 'Green Grass 1'}
# ...

# %%
for record in collection.find():
    print(record)
# Out:
# {'_id': ObjectId('6751c41512e4855fc2e177cf'), 'name': 'sudh', 'class': 'data science masters ', 'timing ': 'flexi'}
# {'_id': ObjectId('6751c51112e4855fc2e177d1'), 'Winner': 'Nikhil', 'Runner': 'Gowtham'}
# {'_id': ObjectId('6751c55012e4855fc2e177d2'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('6751c56412e4855fc2e177d3'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6751c56412e4855fc2e177d4'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6751c56412e4855fc2e177d5'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6751c56412e4855fc2e177d6'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6751c56412e4855fc2e177d7'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('6751c56412e4855fc2e177d8'), 'name': 'Richard', 'address': 'Sky st 331'}
# ...

# %%
random_data = [
    {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'XYZ'},
    {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'},
    {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'},
]

# %%
coll_create.insert_many(random_data)

# %%
collection.insert_many(random_data)
# Out:
# InsertManyResult(['3', '4', '5'], acknowledged=True)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('6751c86712e4855fc2e177e6'), 'name': 'sudh', 'class': 'data science masters ', 'timing ': 'flexi'}
# {'_id': ObjectId('6751c87012e4855fc2e177e7'), 'Winner': 'Nikhil', 'Runner': 'Gowtham'}
# {'_id': ObjectId('6751c87812e4855fc2e177e8'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('6751c88212e4855fc2e177e9'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('6751c56412e4855fc2e177d3'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6751c56412e4855fc2e177d4'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6751c56412e4855fc2e177d5'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6751c56412e4855fc2e177d6'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6751c56412e4855fc2e177d7'), 'name': 'Betty', 'address': 'Green Grass 1'}
# ...

# %%
for record in collection.find():
    print(record)
# Out:
# {'_id': ObjectId('6751c41512e4855fc2e177cf'), 'name': 'sudh', 'class': 'data science masters ', 'timing ': 'flexi'}
# {'_id': ObjectId('6751c51112e4855fc2e177d1'), 'Winner': 'Nikhil', 'Runner': 'Gowtham'}
# {'_id': ObjectId('6751c55012e4855fc2e177d2'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('6751c56412e4855fc2e177d3'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6751c56412e4855fc2e177d4'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6751c56412e4855fc2e177d5'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6751c56412e4855fc2e177d6'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6751c56412e4855fc2e177d7'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('6751c56412e4855fc2e177d8'), 'name': 'Richard', 'address': 'Sky st 331'}
# ...

# %%
coll_create.find_one()
# Out:
# {'_id': ObjectId('6751c41512e4855fc2e177cf'),
#  'name': 'sudh',
#  'class': 'data science masters ',
#  'timing ': 'flexi'}

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('6751c86712e4855fc2e177e6'),
#  'name': 'sudh',
#  'class': 'data science masters ',
#  'timing ': 'flexi'}

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('6751c86712e4855fc2e177e6'),
#  'name': 'sudh',
#  'class': 'data science masters ',
#  'timing ': 'flexi'}

# %%
for record in collection.find({'Winner': 'NikhilMalayakkal'}):
    print(record)
# Out:
# {'_id': ObjectId('6751c89412e4855fc2e177ea'), 'Winner': 'NikhilMalayakkal'}

# %%
for i in coll_create.find({'companyName': 'iNeuron'}):
    print(i)
# Out:
# {'_id': ObjectId('6751c89912e4855fc2e177ec'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('6751c89912e4855fc2e177ed'), 'companyName': 'iNeuron', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('6751c89912e4855fc2e177ee'), 'companyName': 'iNeuron', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': '3', 'companyName': 'iNeuron', 'Faculty': 'XYZ'}
# {'_id': '4', 'companyName': 'iNeuron', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'iNeuron', 'Faculty': 'PQR'}

# %%
for i in coll_create.find({'_id' : {'$gte' : '4'}}):
    print(i)

# %%
coll_create.update_many({'companyName': 'iNeuron'} ,{"$set" :{'companyName': 'pwskills'}} )
# Out:
# UpdateResult({'n': 3, 'electionId': ObjectId('7fffffff0000000000000097'), 'opTime': {'ts': Timestamp(1733411064, 5), 't': 151}, 'nModified': 3, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1733411064, 5), 'signature': {'hash': b'\x9bp\xce\x1a\t\xef\xedj\xb7\xaa\xa2\xfbg\xe4\x9c\x0e\x85\xe5\xf9.', 'keyId': 7387296212421967877}}, 'operationTime': Timestamp(1733411064, 5), 'updatedExisting': True}, acknowledged=True)

# %%
collection.update_many({'Runner': 'Gowtham'} , {'$set': {'Runner': 'VishuPriya Bemineni'}})
# Out:
# UpdateResult({'n': 2, 'electionId': ObjectId('7fffffff0000000000000097'), 'opTime': {'ts': Timestamp(1733413074, 11), 't': 151}, 'nModified': 2, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1733413074, 12), 'signature': {'hash': b't#;\xab\xca\x18S\xa4W\xf5i\xf0qFN\x0e\xb0}\x91;', 'keyId': 7387296212421967877}}, 'operationTime': Timestamp(1733413074, 11), 'updatedExisting': True}, acknowledged=True)

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('6751c41512e4855fc2e177cf'),
#  'name': 'sudh',
#  'class': 'data science masters ',
#  'timing ': 'flexi'}

# %%
records = []

# %%
for record in collection.find(): 
    records.append(record)
    # print(record)

# %%
records
# Out:
# [{'_id': ObjectId('6751c86712e4855fc2e177e6'),
#   'name': 'sudh',
#   'class': 'data science masters ',
#   'timing ': 'flexi'},
#  {'_id': ObjectId('6751c87012e4855fc2e177e7'),
#   'Winner': 'Nikhil',
#   'Runner': 'VishuPriya Bemineni'},
#  {'_id': ObjectId('6751c87812e4855fc2e177e8'),
#   'list_course': ['data science masters ', 'web dev ', 'java with DSA'],
#   'mentor': ['sudhanshu', 'anurag', 'hyder']},
#  {'_id': ObjectId('6751c88212e4855fc2e177e9'),
#   'list_course': ['data science masters ', 'web dev ', 'java with DSA'],
#   'mentor': ['sudhanshu', 'anurag', 'hyder']},
#  {'_id': ObjectId('6751c56412e4855fc2e177d4'),
#   'name': 'Hannah',
#   'address': 'Mountain 21'},
#  {'_id': ObjectId('6751c56412e4855fc2e177dc'),
#   'name': 'William',
#   'address': 'Central st 954'},
#  {'_id': ObjectId('6751c56412e4855fc2e177dd'),
#   'name': 'Chuck',
#   'address': 'Main Road 989'},
#  {'_id': ObjectId('6751c56412e4855fc2e177d5'),
#   'name': 'Michael',
# ...

# %%
for record in records:
    print(record['_id'])
# Out:
# 6751c86712e4855fc2e177e6
# 6751c87012e4855fc2e177e7
# 6751c87812e4855fc2e177e8
# 6751c88212e4855fc2e177e9
# 6751c56412e4855fc2e177d4
# 6751c56412e4855fc2e177dc
# 6751c56412e4855fc2e177dd
# 6751c56412e4855fc2e177d5
# 6751c56412e4855fc2e177d7
# 6751c56412e4855fc2e177da
# 6751c56412e4855fc2e177de
# 6751c56412e4855fc2e177d3
# 6751c56412e4855fc2e177d6
# 6751c56412e4855fc2e177d8
# 6751c56412e4855fc2e177d9
# 6751c56412e4855fc2e177db
# 6751c89412e4855fc2e177eb
# 6751c89412e4855fc2e177ea
# 6751c89912e4855fc2e177ec
# 6751c89912e4855fc2e177ee
# 6751c89912e4855fc2e177ed
# 3
# 4
# 5
# 675b2bf7d4f040202bc71e4a
# 675b2c02d4f040202bc71e4b
# 675b2c02d4f040202bc71e4c
# 675b2c03d4f040202bc71e4d
# 675b2c0ed4f040202bc71e4e

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('6751c41512e4855fc2e177cf'), 'name': 'sudh', 'class': 'data science masters ', 'timing ': 'flexi'}
# {'_id': ObjectId('6751c51112e4855fc2e177d1'), 'Winner': 'Nikhil', 'Runner': 'VishuPriya Bemineni'}
# {'_id': ObjectId('6751c55012e4855fc2e177d2'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('6751c56412e4855fc2e177d3'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6751c56412e4855fc2e177d4'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6751c56412e4855fc2e177d5'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6751c56412e4855fc2e177d6'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6751c56412e4855fc2e177d7'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('6751c56412e4855fc2e177d8'), 'name': 'Richard', 'address': 'Sky st 331'}
# ...

# %%
coll_create.drop()

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('6751c86712e4855fc2e177e6'), 'name': 'sudh', 'class': 'data science masters ', 'timing ': 'flexi'}
# {'_id': ObjectId('6751c87012e4855fc2e177e7'), 'Winner': 'Nikhil', 'Runner': 'VishuPriya Bemineni'}
# {'_id': ObjectId('6751c87812e4855fc2e177e8'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('6751c88212e4855fc2e177e9'), 'list_course': ['data science masters ', 'web dev ', 'java with DSA'], 'mentor': ['sudhanshu', 'anurag', 'hyder']}
# {'_id': ObjectId('6751c56412e4855fc2e177d3'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6751c56412e4855fc2e177d4'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6751c56412e4855fc2e177d5'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6751c56412e4855fc2e177d6'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# ...

# %%
collection.drop()
