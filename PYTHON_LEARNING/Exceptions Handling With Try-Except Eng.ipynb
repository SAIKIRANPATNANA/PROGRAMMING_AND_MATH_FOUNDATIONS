# %%
a = 10

# %%
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a/0
#
# ZeroDivisionError: division by zero

# %%
f = open("test.txt" , 'r')
print("this is my print")
# Out:
# this is my print

# %%
try:
    f = open("test.txt" , 'r')
except Exception as e  :
    print("there is some issuewith my code ", e)
print("this is my print")
a = 10
a
# Out:
# this is my print
# 10

# %%
try:
    f = open('test.txt', 'r')
except Exception as e:
    print('There is some error in my code', e)

# %%
try:
    f = open("test.txt" , 'w')
    f.write("this is my msg")

except Exception as e :
    print("there is some issue with my code ", e)
else : 
        f.close()
        print("this block will execute once try will execute itself without an exception")
# Out:
# this block will execute once try will execute itself without an exception

# %%
try:
    f = open('test.txt', 'w')
    f.write('this is my stuff')
except Exception as e:
    print('There is some issue with my code', e)
else:
    f.close()
    print('Success, There is no issue with my code')
# Out:
# Success, There is no issue with my code

# %%
try:
    f = open('test.txt', 'w')
    f.write('this is my stuff')
except Exception as e:
    print('There is some issue with my code', e)
else:
    f.close()
    print('Success, There is no issue with my code')
# Out:
# Success, There is no issue with my code

# %%
try:
    f = open('test1.txt', 'r')
    print(f.read())
except Exception as e:
    print('There is some issue with my code', e)
else:
    f.close()
    print('Success, There is no issue with my code')
# Out:
# The Mysterious Affair at Styles
# The Secret Adversary
# The Murder on the Links
# The Man in the Brown Suit
# The Secret of Chimneys
# The Murder of Roger Ackroyd
# The Big Four
# The Mystery of the Blue Train
# The Seven Dials Mystery
# The Murder at the Vicarage
# Giant's Bread
# The Floating Admiral
# The Sittaford Mystery
# Peril at End House
# Lord Edgware Dies
# Murder on the Orient Express
# Unfinished Portrait
# Why Didn't They Ask Evans?
# Three Act Tragedy
# Death in the Clouds
#
# Success, There is no issue with my code

# %%
try:
    f = open('test1.txt', 'w')
    f.write('this is my stuff')
except Exception as e:
    print('There is some issue with my code', e)
else:
    f.close()
    print('Success, There is no issue with my code')
# Out:
# Success, There is no issue with my code

# %%
try:
    f = open("test1.txt" , 'r')
    f.write("this is my msg")

except Exception as e :
    print("there is some issue with my code ", e)
else: 
        f.close()
        print("this block will execute once try will execute itself without an exception")
# Out:
# there is some issue with my code  not writable

# %%
try:
    f = open("test1.txt" , 'r')
    f.write("this is my msg")
except Exception as e:
    print(e)
finally :
    print("this will always execute")
# Out:
# not writable
# this will always execute

# %%
try:
    f = open("test1.txt" , 'r')
    f.write("this is my msg")

except Exception as e :
    print("there is some issue with my code ", e)
else : 
        f.close()
        print("this block will execute once try will execute itself without an exception")
        
finally :
    
    print("i will execute always ")
# Out:
# there is some issue with my code  not writable
# i will execute always

# %%
try:
    f = open("test1.txt" , 'w')
    f.write("this is my msg")

except Exception as e :
    print("there is some issue with my code ", e)
else : 
        f.close()
        print("this block will execute once try will execute itself without an exception")
        
finally :
    
    print("i will execute always ")
# Out:
# this block will execute once try will execute itself without an exception
# i will execute always

# %%
try: 
    print(1/0)
except Exception as e:
    print(e)
else:
    print('Love You Like Anything Else Prasanna..!')
finally:
    print('Always Love You Prasanna')
# Out:
# division by zero
# Always Love You Prasanna

# %%
try: 
    print(1/2)
except Exception as e:
    print(e)
else:
    print('Love You Like Anything Else Prasanna..!')
finally:
    print('Always Love You Prasanna')
# Out:
# 0.5
# Love You Like Anything Else Prasanna..!
# Always Love You Prasanna

# %%
try:
    print('Hey Prasanna, I Love You!')
    a = int(input('enter your response prasanna?'))
    if(not a):
        print(1/a)
except  Exception as e:
    print("Sorry, Saikiran! I am not interested in you ra!")
else:
    print("I Love You too ra Sai Kiran!")
finally:
    if(not a):
        print("It's Ok Macha!")
    else:
        print("Thank You Prasanna!")
# Out:
# Hey Prasanna, I Love You!
# enter your response prasanna? 1
# I Love You too ra Sai Kiran!
# Thank You Prasanna!

# %%
try: 
    f = open("try.txt", 'r+')
except Exception as e:
    print(e)
else:
    print('No Error! , Code Executed Successfully')
finally:
    print('It Happens Macha!')
# Out:
# [Errno 2] No such file or directory: 'try.txt'
# It Happens Macha!
