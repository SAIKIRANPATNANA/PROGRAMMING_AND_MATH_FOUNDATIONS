# %%
try :
    a = 10 
    10/0
    
except ZeroDivisionError as e :
    print(e)
# Out:
# division by zero

# %%
try:
    print(1/0)
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
try :
    int("sudh")
except (ValueError , TypeError) as e :
    print(e)
# Out:
# invalid literal for int() with base 10: 'sudh'

# %%
try:
    int('psk')
except (TypeError, ValueError) as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'psk'

# %%
try :
    int("sudh")
except  :
    print("this will catch an error")
# Out:
# this will catch an error

# %%
try:
    int('psk')
except:
    print('Prasanna!')
# Out:
# Prasanna!

# %%
try :
    import sudh
except ImportError as e : 
    print(e)
# Out:
# No module named 'sudh'

# %%
try:
    import prasanna
except ImportError as e:
    print(e)
# Out:
# No module named 'prasanna'

# %%
try :
    d = {1: [3,4,5,6] , "key" :"sudh"}
    d["key10"]
except KeyError as e : 
    print(e)
# Out:
# 'key10'

# %%
try: 
    bb = {'winner' : 'nikhil', 'runner': 'gowtham'}
    print(bb['top3'])
except KeyError as e:
    print(e)
# Out:
# 'top3'

# %%
try :
    "sudh".test()
except AttributeError as e :
    print(e)
# Out:
# 'str' object has no attribute 'test'

# %%
try: 
    'prassan'.love()
except AttributeError as e:
    print(e)
# Out:
# 'str' object has no attribute 'love'

# %%
try :
    l = [1,2,3,3]
    l[10]
except IndexError as e :
    print(e)
# Out:
# list index out of range

# %%
try:
    l = [1,2,3,4]
    print(l[4])
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
try :
    123 + "sudh"
except TypeError as e :
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    print(123+'prasanna')
except TypeError as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try :
    with open("test.txt" , 'r') as f :
        f.read()
except FileNotFoundError as e :
    print(e)
# Out:
# [Errno 2] No such file or directory: 'test.txt'

# %%
try:
    with open('pra.txt', 'r') as f:
        print(f.read())
except  FileNotFoundError as e:
    print(e)
# Out:
# [Errno 2] No such file or directory: 'pra.txt'

# %%
try :
    with open("test.txt" , 'r') as f :
        f.read()
except Exception as e :
    print("test " , e)
except FileNotFoundError as e :
    print("this is my file not found type error " , e)
# Out:
# test  [Errno 2] No such file or directory: 'test.txt'

# %%
try:
    with open('pra.txt', 'r') as f:
        print(f.read())
except FileNotFoundError as e:
    print(e)
except Exception as e:
    print('Prasanna!')
# Out:
# [Errno 2] No such file or directory: 'pra.txt'

# %%
try:
    with open('pra.txt', 'r') as f:
        print(f.read())
except Exception as e:
    print('Prasanna!')
except FileNotFoundError as e:
    print(e)
# Out:
# Prasanna!

# %%
def test(file):
    try :
        with open(file, 'r') as f :
            f.read()
    except Exception as e :
        print("test " , e)
    except FileNotFoundError as e :
        print("this is my file not found type error " , e)
