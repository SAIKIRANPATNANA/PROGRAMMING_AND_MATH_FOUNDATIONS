# %%
pow = lambda a,b: a**b
pow(1,2)
# Out:
# 1

# %%
n = 3 
p = 2

# %%
def test(n,p):
    return n**p

# %%
test(3,2)
# Out:
# 9

# %%
test(9,4)
# Out:
# 6561

# %%
a = lambda n,p : n**p

# %%
a(3,2)
# Out:
# 9

# %%
a(9,4)
# Out:
# 6561

# %%
add = lambda x,y : x+y

# %%
add(234,34)
# Out:
# 268

# %%
c_to_f = lambda c : (9/5)*c+32

# %%
c_to_f(34)
# Out:
# 93.2

# %%
max_two = lambda x,y : x if x> y else y

# %%
max_two = lambda x,y : max(x,y)

# %%
max_two(4,56)
# Out:
# 56

# %%
s = "pwskills"

# %%
len_st = lambda s : len(s)

# %%
len_st(s)
# Out:
# 8

# %%
mul = lambda x,y: x*y

# %%
mul(1,2)
# Out:
# 2

# %%
import math

# %%
logging = lambda x: math.log2(x)

# %%
logging(2)
# Out:
# 1.0

# %%
temp_f = lambda c: (9*c/5) + 32

# %%
temp_f(0)
# Out:
# 32.0

# %%
primes = lambda p: [num for num in range(1,p+1) if all(num%i!=0 for i in range(2,num)) and num!=1]

# %%
primes(20)
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19]

# %%
r = lambda a,b,c: max(a,b,c)

# %%
r(1,2,3)
# Out:
# 3
