# %%
class pwskills:
    
    def __init__(self, course_price , course_name):
        self.__course_price = course_price
        self.course_name = course_name
        
    @property
    def course_price_access(self):
        return self.__course_price
    
    @course_price_access.setter
    def course_price_set(self , price):
        if price <= 3500:
            pass
        else :
            self.__course_price = price
            
    @course_price_access.deleter 
    def course_price_del(self):
        del  self.__course_price

# %%
class PWSkills:
    def __init__(self,course,price):
        self.course = course
        self.price = price
    @property
    def getCoursePrice(self):
        return self.price
    @getCoursePrice.setter
    def setCoursePrice(self,price):
        self.price = price if price>=0 else 0
        return self.price
    @getCoursePrice.deleter
    def dltCoursePrice(self):
        del self.price

# %%
pw = PWSkills('dsm',3500)

# %%
pw.getCoursePrice
# Out:
# 3500

# %%
pw.course
# Out:
# 'dsm'

# %%
pw.price
# Out:
# 3500

# %%
pw.setCoursePrice = 7000

# %%
pw.getCoursePrice
# Out:
# 7000

# %%
del pw.dltCoursePrice

# %%
pw.getCoursePrice
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 pw.getCoursePrice
#
# Cell In[66], line 7, in PWSkills.getCoursePrice(self)
#       5 @property
#       6 def getCoursePrice(self):
# ----> 7     return self.price
#
# AttributeError: 'PWSkills' object has no attribute 'price'

# %%
pw.course
# Out:
# 'dsm'

# %%
pw.price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 pw.price
#
# AttributeError: 'PWSkills' object has no attribute 'price'

# %%
pw.setCoursePrice = 2000

# %%
pw.price
# Out:
# 2000

# %%
pw.getCoursePrice
# Out:
# 2000

# %%
pw = pwskills(3500 , "data science masters")

# %%
pw.course_price_access
# Out:
# 3500

# %%
del pw.course_price_del

# %%
pw.course_price_set = 2

# %%
pw.course_price_access
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pw.course_price_access
#
# Cell In[8], line 9, in pwskills.course_price_access(self)
#       7 @property
#       8 def course_price_access(self):
# ----> 9     return self.__course_price
#
# AttributeError: 'pwskills' object has no attribute '_pwskills__course_price'

# %%
pw.course_price_set = 4500

# %%
pw.course_price_access
# Out:
# 4500

# %%
pw.course_name
# Out:
# 'data science masters'

# %%
pw._pwskills__course_price
# Out:
# 4500
