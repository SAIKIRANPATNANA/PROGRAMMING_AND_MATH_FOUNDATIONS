# %%
# !pip install bokeh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bokeh in /usr/local/lib/python3.8/dist-packages (2.4.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.8/dist-packages (from bokeh) (4.5.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.8/dist-packages (from bokeh) (8.4.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.8/dist-packages (from bokeh) (6.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.8/dist-packages (from bokeh) (3.1.2)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.8/dist-packages (from bokeh) (6.0)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.8/dist-packages (from bokeh) (23.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.8/dist-packages (from bokeh) (1.22.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2>=2.9->bokeh) (2.1.2)

# %%
import warnings as warn
warn.filterwarnings('ignore')

# %%
# !pip install bokeh
# Out:
# DEPRECATION: Loading egg at /home/user/anaconda3/lib/python3.11/site-packages/dlib-19.24.99-py3.11-linux-x86_64.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..
# Requirement already satisfied: bokeh in /home/user/anaconda3/lib/python3.11/site-packages (3.2.1)
# Requirement already satisfied: Jinja2>=2.9 in /home/user/.local/lib/python3.11/site-packages (from bokeh) (3.1.3)
# Requirement already satisfied: contourpy>=1 in /home/user/.local/lib/python3.11/site-packages (from bokeh) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in /home/user/.local/lib/python3.11/site-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in /home/user/.local/lib/python3.11/site-packages (from bokeh) (23.2)
# Requirement already satisfied: pandas>=1.2 in /home/user/.local/lib/python3.11/site-packages (from bokeh) (2.2.1)
# Requirement already satisfied: pillow>=7.1.0 in /home/user/.local/lib/python3.11/site-packages (from bokeh) (10.2.0)
# Requirement already satisfied: PyYAML>=3.10 in /home/user/.local/lib/python3.11/site-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /home/user/.local/lib/python3.11/site-packages (from bokeh) (6.4)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/user/anaconda3/lib/python3.11/site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/user/anaconda3/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/.local/lib/python3.11/site-packages (from pandas>=1.2->bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/user/anaconda3/lib/python3.11/site-packages (from pandas>=1.2->bokeh) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/.local/lib/python3.11/site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/user/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e313dd7f-dec7-459e-b607-587f092f8324">Loading BokehJS ...</span>
#     </div>

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a48aadde-4c0b-4113-8549-d6668bf252f8">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure , output_file, show
from bokeh.sampledata.iris import flowers

# %%
from bokeh.plotting import figure, output_file, show

# %%
from bokeh.sampledata.iris import flowers

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(flowers)
# Out:
# pandas.core.frame.DataFrame

# %%
output_file('test.html')
p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.circle(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div id="d2e30c80-1c42-41df-bf2a-d34c67f0e7c8" data-root-id="p1044" style="display: contents;"></div>
# Opening in existing browser session.

# %%
output_file('test.html')
p = figure(title = 'test flower')
p.xaxis.axis_label = "petal_length"
p.yaxis.axis_label = "petal_width"
p.line(flowers['petal_length'] , flowers['petal_width'])
show(p)
# Out:
#   <div id="af3e9884-0515-4a77-a36a-de65ac792991" data-root-id="p1087" style="display: contents;"></div>
# Opening in existing browser session.

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line graph")
p.line(x,y)
show(p)
# Out:
#   <div id="f3b3b49a-4417-4dba-9cae-0d73632cb65b" data-root-id="p1130" style="display: contents;"></div>
# Opening in existing browser session.

# %%
x = [3,4,5,6,7]
y = [4,5,6,7,4]
output_file("line.html")
p = figure(title = "line graph")
p.scatter(x,y , size = 20,fill_color = 'red',legend_label = 'this is my data point')
show(p)
# Out:
#   <div id="fed0f864-e094-4157-b217-03cb61a118e2" data-root-id="p1169" style="display: contents;"></div>
# Opening in existing browser session.
