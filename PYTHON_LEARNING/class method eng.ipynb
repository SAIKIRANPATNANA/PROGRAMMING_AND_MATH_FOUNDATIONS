# %%
class pwskills:
    def __init__(self, name , email):
        self.name = name
        self.email = email
    def student_details(self):
        print(self.name , self.email)

# %%
class PWSkills:
    def __init__(self, name, email):
        self.name = name
        self.email = email
    def getStudentStuff(self):
        return self.name, self.email

# %%
pwskills = PWSkills('sai', 'psk@143')

# %%
pwskills.getStudentStuff()
# Out:
# ('sai', 'psk@143')

# %%
pw = pwskills("sudh" , "sudh@gmail.com")

# %%
pw.name
# Out:
# 'sudh'

# %%
pw.email
# Out:
# 'sudh@gmail.com'

# %%
pw.student_details()
# Out:
# sudh sudh@gmail.com

# %%
pwskills.name
# Out:
# 'sai'

# %%
pwskills.email
# Out:
# 'psk@143'

# %%
class pwskills1:
    def __init__(self, name , email):
        
        self.name = name
        self.email = email
    
    @classmethod
    def details(cls , name1 , email1):
        return cls(name1 , email1)
    
    def student_details(self):
        print(self.name , self.email)

# %%
pw1 = pwskills1.details("mohan" , "mohan@gamil.com")

# %%
pw1.name
# Out:
# 'mohan'

# %%
pw1.email
# Out:
# 'mohan@gamil.com'

# %%
pw1.student_details()
# Out:
# mohan mohan@gamil.com

# %%
pwskills1 = PWSkills1('sai','psk@143')

# %%
pwskills1.name
# Out:
# 'sai'

# %%
pwskills1.email
# Out:
# 'psk@143'

# %%
class PWSkills1:
    def __init__(self, name, email):
        self.name = name
        self.email = email
    @classmethod
    def getStudentDetails(cls,name,email):
        return cls(name,email)
    def getStudentStuff(self):
        return self.name, self.email

# %%
pwskills2 = PWSkills1.getStudentDetails('kiran','prasanna@143')

# %%
pwskills2.name
# Out:
# 'kiran'

# %%
pwskills2.email
# Out:
# 'prasanna@143'

# %%
class pwskills2:    
    mobile_number = 9134534535
    
    def __init__(self, name , email):
        
        self.name = name
        self.email = email
    
    @classmethod
    def change_number(cls, mobile):
        pwskills2.mobile_number = mobile
    
    @classmethod
    def details(cls , name1 , email1):
        return cls(name1 , email1)
    
    def student_details(self):
        print(self.name , self.email,pwskills2.mobile_number)

# %%
class PWSkills3:
    mobile_number = 6304097726
    def __init__(self, name, email):
        self.name = name 
        self.email = email
    @classmethod
    def alterMobileNumber(cls,number):
        PWSkills3.mobile_number = number
    @classmethod
    def getStudentDetails(cls, name, email):
        return cls(name, email)
    def getStudentStuff(self):
        print(self.name, self.email, PWSkills3.mobile_number)

# %%
pwskills3 = PWSkills3('sai', 'psk@143')

# %%
pwskills3.name
# Out:
# 'sai'

# %%
pwskills3.email
# Out:
# 'psk@143'

# %%
pwskills3.getStudentStuff()
# Out:
# sai psk@143 6304097726

# %%
pwskills31 = pwskills3.getStudentDetails('kiran','prasanna@143')

# %%
pwskills31.getStudentStuff()
# Out:
# kiran prasanna@143 6304097726

# %%
pwskills3.name
# Out:
# 'sai'

# %%
pwskills3.alterMobileNumber('6300006765')

# %%
pwskills3.getStudentStuff()
# Out:
# sai psk@143 6300006765

# %%
pwskills3.mobile_number
# Out:
# '6300006765'

# %%
PWSkills3.mobile_number
# Out:
# '6300006765'

# %%
pwskills31.mobile_number
# Out:
# '6300006765'

# %%
pwskills31.getStudentStuff()
# Out:
# kiran prasanna@143 6300006765

# %%
pw2_obj = pwskills2("sohil" , "sohil@gmail.com")

# %%
pw2_obj.details("sudh" , "sudh@gmail.com")

# %%
pw2_obj.name
# Out:
# 'sohil'

# %%
pw2_obj.change_number(534553534)

# %%
pw2_obj.mobile_number
# Out:
# 534553534

# %%
pwskills2.mobile_number
# Out:
# 534553534

# %%
pwskills2.change_number(9233345344)

# %%
pwskills2.mobile_number
# Out:
# 9233345344

# %%
pwskills2.mobile_number
# Out:
# 9233345344

# %%
pw2 = pwskills2.details("sohan" , "sohan@gmail.com")

# %%
pw2.student_details()
# Out:
# sohan sohan@gmail.com 9233345344

# %%
pw2_obj = pwskills2("rohan" , "rohan@gmail.com")

# %%
pw2_obj.student_details()
# Out:
# rohan rohan@gmail.com 9233345344

# %%
class pwskills3:
    
    mobile_number = 9134534535
    
    def __init__(self, name , email):
        
        self.name = name
        self.email = email
    
    @classmethod
    def change_number(cls, mobile):
        pwskills2.mobile_number = mobile
    
    @classmethod
    def details(cls , name1 , email1):
        return cls(name1 , email1)
    
    def student_details(self):
        print(self.name , self.email,pwskills2.mobile_number)

# %%
def course_details(cls ,course_name ):
    print("course details" , course_name)

# %%
pwskills3.course_details = classmethod(course_details)

# %%
pwskills3.course_details("data science masters")
# Out:
# course details data science masters

# %%
def committed(cls,girl_name):
    print(girl_name)

# %%
PWSkills3.committed = classmethod(committed)

# %%
pwskills3 = PWSkills3('sai', 'psk@143')

# %%
pwskills3.committed('Prasanna Vadithya')
# Out:
# Prasanna Vadithya

# %%
pwskills3.getStudentStuff()
# Out:
# sai psk@143 6300006765

# %%
delattr(PWSkills3, 'committed')

# %%
pwskills3.committed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 pwskills3.committed
#
# AttributeError: 'PWSkills3' object has no attribute 'committed'

# %%
del PWSkills3.mobile_number

# %%
pwskills3.mobile_number
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 pwskills3.mobile_number
#
# AttributeError: 'PWSkills3' object has no attribute 'mobile_number'

# %%
pw3 = pwskills3("sudh" , "sudh@gmail.com")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 pw3 = pwskills3("sudh" , "sudh@gmail.com")
#
# TypeError: 'PWSkills3' object is not callable

# %%
pw3.course_details("web dev")
# Out:
# course details web dev

# %%
class pwskills4:
    
    mobile_number = 9134534535
    
    def __init__(self, name , email):
        
        self.name = name
        self.email = email
    
    @classmethod
    def change_number(cls, mobile):
        pwskills2.mobile_number = mobile
    
    @classmethod
    def details(cls , name1 , email1):
        return cls(name1 , email1)
    
    def student_details(self):
        print(self.name , self.email,pwskills2.mobile_number)

# %%
del pwskills4.change_number

# %%
pwskills4.change_number(2432535345)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 pwskills4.change_number(2432535345)
#
# AttributeError: type object 'pwskills4' has no attribute 'change_number'

# %%
delattr(pwskills4 , "details")

# %%
pwskills4.mobile_number
# Out:
# 9134534535

# %%
delattr(pwskills4 , "mobile_number")

# %%
pwskills4.mobile_number
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 pwskills4.mobile_number
#
# AttributeError: type object 'pwskills4' has no attribute 'mobile_number'

# %%
delattr(pwskills4,"student_details")

# %%
pwskills4
# Out:
# __main__.pwskills4
