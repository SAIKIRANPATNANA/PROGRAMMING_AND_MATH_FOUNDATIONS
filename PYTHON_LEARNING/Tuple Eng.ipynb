# %%
#str methods: endswith, startswith, join, reverse, isupper, islower, isalnum, upper, len, lower,  isalpha, isspace, isdigit, strip-lr, 
#list methods: pop, remove, apend, extend, sort, reverse, join, index, min, max len
# tuple methods: count, index, min, max, len

# %%
li = [2,3]
li += [4]
li.insert(1,5)

# %%
li.
# Out:
# [2, 5, 3, 4]

# %%
li.remove(5)

# %%
li
# Out:
# [2, 3, 4]

# %%
t = (1,2,3,4)
print(t.index(1), t.count(2))
# Out:
# 0 1

# %%
"sai"[0] = 'S'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 "sai"[0] = 'S'
#
# TypeError: 'str' object does not support item assignment

# %%
type(t)
# Out:
# tuple

# %%
t1 = (1,2,3,4,45,45.45 , 45+7j , "sudh" , True)

# %%
type(t1)
# Out:
# tuple

# %%
l = [1,2,3,4]

# %%
type(l)
# Out:
# list

# %%
t1
# Out:
# (1, 2, 3, 4, 45, 45.45, (45+7j), 'sudh', True)

# %%
t1[0]
# Out:
# 1

# %%
type(t1[-3])
# Out:
# complex

# %%
t1[-3].imag
# Out:
# 7.0

# %%
t1
# Out:
# (1, 2, 3, 4, 45, 45.45, (45+7j), 'sudh', True)

# %%
t1[7]
# Out:
# 'sudh'

# %%
t1[::-1]
# Out:
# (True, 'sudh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
t1 = t1[::-1]

# %%
t1
# Out:
# (True, 'sudh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
t1[0:3]
# Out:
# (True, 'sudh', (45+7j))

# %%
t1
# Out:
# (True, 'sudh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
s = 'sai'

# %%
s += 'b'

# %%
#in strings assigning is not possible but adding is  possible while in tuples both are not possible 

t1.count(4)
# Out:
# 1

# %%
t1.count("abc")
# Out:
# 0

# %%
t1.index(1)
# Out:
# 0

# %%
t1.index("sudh")
# Out:
# 1

# %%
t1
# Out:
# (True, 'sudh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
t1.count(True)
# Out:
# 2

# %%
t1.count(1)
# Out:
# 2

# %%
t1
# Out:
# (True, 'sudh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
t1[0]
# Out:
# True

# %%
t1[-1]
# Out:
# 1

# %% [markdown]
# """Tuple are basically follows  Immutability concepts where it is not going to allow to change any element at a perticular index"""

# %%
t1[0] = 345 #tuples and string are immutable.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 t1[0] = 345 #tuples and string are immutable.
#
# TypeError: 'tuple' object does not support item assignment

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
t1 += [1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 t1 += [1]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
l[0]
# Out:
# 1

# %%
l[0] = 100

# %%
l
# Out:
# [100, 2, 3, 4]

# %%
t1
# Out:
# (True, 'sudh', (45+7j), 45.45, 45, 4, 3, 2, 1)

# %%
for i in t1 :
    print(i , type(i))
# Out:
# True <class 'bool'>
# sudh <class 'str'>
# (45+7j) <class 'complex'>
# 45.45 <class 'float'>
# 45 <class 'int'>
# 4 <class 'int'>
# 3 <class 'int'>
# 2 <class 'int'>
# 1 <class 'int'>

# %%
t2 = (1,2,3,3,4)

# %%
t2
# Out:
# (1, 2, 3, 3, 4)

# %%
t2 * 3
# Out:
# (1, 2, 3, 3, 4, 1, 2, 3, 3, 4, 1, 2, 3, 3, 4)

# %%
max(t2)
# Out:
# 4

# %%
min(t2)
# Out:
# 1

# %%
t1 = (1,2,32,4)
t2 = (4,5,6,7,8)

# %%
t1+t2
# Out:
# (1, 2, 32, 4, 4, 5, 6, 7, 8)

# %%
(t1,t2)
# Out:
# ((1, 2, 32, 4), (4, 5, 6, 7, 8))

# %%
t3 = (t1,t2)

# %%
t3
# Out:
# ((1, 2, 32, 4), (4, 5, 6, 7, 8))

# %%
t4 = ((1,2,3,4,5) , [1,3,5,6,7,8])

# %%
t4
# Out:
# ((1, 2, 3, 4, 5), [1, 3, 5, 6, 7, 8])

# %%
del t4

# %%
t4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 t4
#
# NameError: name 't4' is not defined

# %%
t1
# Out:
# (1, 2, 32, 4)

# %%
len(t1)
# Out:
# 4

# %%
t1
# Out:
# (1, 2, 32, 4)

# %%
"sudh" in t1
# Out:
# False

# %%
2 in t1
# Out:
# True

# %%
t1 = (1,2,3,4)

# %%
t1.index(2)
# Out:
# 1

# %%
t1.count(1)
# Out:
# 1

# %%
t3 = (t1)

# %%
t1
# Out:
# (1, 2, 3, 4)

# %%
t3
# Out:
# (1, 2, 3, 4)

# %%
t3 = (t1,)

# %%
t3
# Out:
# ((1, 2, 3, 4),)

# %%
t5 = (True,1,1,0,False,-1)

# %%
t5.count(True)
# Out:
# 3

# %%
t5.count(0)
# Out:
# 2

# %%
t5.count(False)
# Out:
# 2

# %%
t5.count(-1)
# Out:
# 1

# %%
t5.count(True)
# Out:
# 3

# %%
(True, 1, 1, 1).count(1)
# Out:
# 4

# %%
(True, 1, 1, 1).count(True)
# Out:
# 4
