# %%
l = [1,2,3,4,45,5]

# %%
def test(l):
    l1 = []
    for i in l :
        l1.append(i**2)
    return l1

# %%
test(l)
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
li = [1,2,3,4]
def sqrt(x):
    return round(x**0.5,2)

# %%
list(map(sqrt,li))
# Out:
# [1.0, 1.41, 1.73, 2.0]

# %%
list(map(sqrt,li))
# Out:
# [1.0, 1.41, 1.73, 2.0]

# %%
def sq(x):
    return x**2

# %%
list(map(sq , l))
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
list(map(lambda x : x**2 , l ))
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
list(map(lambda x: round(x**0.5,2), li))
# Out:
# [1.0, 1.41, 1.73, 2.0]

# %%
list(map(lambda x : x+10 , l ))
# Out:
# [11, 12, 13, 14, 55, 15]

# %%
list(map(lambda x : str(x) , l ))
# Out:
# ['1', '2', '3', '4', '45', '5']

# %%
l1 = [1,2,3,4,5]
l2 = [6,7,8,9,10]

# %%
list(map(lambda x,y : x+y, l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
f = lambda x,y : x+y

# %%
list(map(f, l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
list(map(lambda x,y :x+y , l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
import math

# %%
list(map(lambda x,y : round((math.log10(x)*math.log2(y)),2), l1,l2))
# Out:
# [0.0, 0.85, 1.43, 1.91, 2.32]

# %%
list(map(f , l1,l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
f = lambda x,y :x+y

# %%
s = "pwskills"

# %%
list(map(lambda x : x.upper()  , s))
# Out:
# ['P', 'W', 'S', 'K', 'I', 'L', 'L', 'S']

# %%
from functools import  reduce

# %%
l = [1,2,3,4,5,4]

# %%
reduce(lambda x , y : x+y , l)
# Out:
# 19

# %%
def add(x,y):
    return x+y

# %%
reduce (add , l)
# Out:
# 19

# %%
reduce(lambda x , y , z : x+y+z , l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 reduce(lambda x , y , z : x+y+z , l)
#
# TypeError: <lambda>() missing 1 required positional argument: 'z'

# %%
l
# Out:
# [1, 2, 3, 4, 5, 4]

# %%
reduce(lambda x , y : x+y , [])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 reduce(lambda x , y : x+y , [])
#
# TypeError: reduce() of empty iterable with no initial value

# %%
reduce(lambda x , y : x+y , [1])
# Out:
# 1

# %%
reduce(lambda x , y : x*y , [1])
# Out:
# 1

# %%
l
# Out:
# [1, 2, 3, 4, 5, 4]

# %%
reduce(lambda x,y : x if x> y else y , l)
# Out:
# 5

# %%
l
# Out:
# [1, 2, 3, 4, 5, 4]

# %%
list(filter(lambda x: x>2, l))
# Out:
# [3, 4, 5, 4]

# %%
set(filter(lambda x: not x%2, l))
# Out:
# {2, 4}

# %%
list(filter(lambda x: x%2, l))
# Out:
# [1, 3, 5]

# %%
list(filter(lambda x : x % 2 ==0 , l))
# Out:
# [2, 4, 4]

# %%
list(filter(lambda x : x % 2 !=0 , l))
# Out:
# [1, 3, 5]

# %%
l1 = [-2,4,5,6,-3,-6,-7]

# %%
list(filter(lambda x : x < 0 , l1))
# Out:
# [-2, -3, -6, -7]

# %%
list(filter(lambda x : x >= 0 , l1))
# Out:
# [4, 5, 6]

# %%
l2 = ["sudh" , "pwskills" , "kumar" , "bengalore" , "krish"]

# %%
list(filter(lambda x : len(x) < 6 , l2))
# Out:
# ['sudh', 'kumar', 'krish']

# %%
list(filter(lambda x: len(x)>6, l2))
# Out:
# ['pwskills', 'bengalore']

# %%
import numpy as np

# %%
prime = lambda li: list(filter(lambda x: all(x%i!=0 for i in range(2,x)) and x!=1, li))

# %%
prime(set(np.random.randint(1,25,10)))
# Out:
# [3, 5, 11, 13, 19, 23]

# %%
list(filter(lambda x: x>0, [-1,-2,1,2]))
# Out:
# [1, 2]

# %%
list(map(lambda x: x**2,li))
# Out:
# [1, 4, 9, 16]

# %%
# map(fn,ele) returns obj
# filter(fn,ele) returns obj
#lambda ele: opn

# %%
type(filter(lambda x: all(x%i!=0 for i in range(2,x)) and x!=1, li))
# Out:
# filter
