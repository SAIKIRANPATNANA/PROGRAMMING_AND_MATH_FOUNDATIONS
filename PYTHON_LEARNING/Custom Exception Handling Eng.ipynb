# %%
age = int(input("enter your age"))
# Out:
# enter your age 10

# %%
class validateage(Exception) : 
    def __init__(self, msg) :
        self.msg = msg

# %%
def validate_age(age) : 
    if age < 0 : 
        raise validateage("age should not be lesser then zero" )
    elif age > 200 : 
        raise validateage("age is too high " )
        
    else :
        print("age is valid" )

# %%
try : 
    age = int(input("enter your age"))
    validate_age(age)
except validateage as e : 
    print(e)
# Out:
# enter your age 234322
# age is too high

# %%
class RightToVote(Exception):
    def __init__(self, msg):
        self.msg = msg

# %%
def ValidateRightToVote(age):
    if(age<0):
        raise RightToVote('Entered Invalid Age!')
    elif(age<18):
        raise RightToVote('Sorry! You are not eligible to vote...')

# %%
try:
    age = int(input("Enter Age: "))
    ValidateRightToVote(age)
except Exception as e:
    print(e)
else:
    print('You are eligible to vote!')
finally:
    print('You are my divine Prasanna, Love you like hell ra..!')
# Out:
# Enter Age:  18
# You are eligible to vote!
# You are my divine Prasanna, Love you like hell ra..!

# %%
class RTV(Exception):
    def __init__(self,msg):
        self.msg = msg
def ValidateRTV(age):
    if(age>=18):
        return;
    else: 
        raise RTV('You are not eligible for RTV!')
try: 
    age = int(input("enter age?"))
    ValidateRTV(age)
except Exception as e:
    print(e)
else:
    print('Bravo, Vote For The Right!')
finally:
    print("Jai Hind!")
# Out:
# enter age? -1
# You are not eligible for RTV!
# Jai Hind!
