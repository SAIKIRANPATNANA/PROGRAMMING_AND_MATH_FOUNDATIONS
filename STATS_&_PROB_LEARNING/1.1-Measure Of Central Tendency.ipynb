# %% [markdown]
# ## Measure Of Central Tendency

# %%
## Mean (Average)
age=[12,13,14,21,24]

# %%
(12+13+14+21+24)/5
# Out:
# 16.8

# %%
import numpy as np
np.mean(age)
# Out:
# 16.8

# %%
weights=[45,34,55,76,45,35,89,98,75]

# %%
np.mean(weights)
# Out:
# 61.333333333333336

# %%
weights=[45,34,55,76,45,35,89,98,75,1000]

# %%
np.mean(weights)
# Out:
# 155.2

# %%
## Median

# %%
np.median(weights)
# Out:
# 65.0

# %%
## mode

# %%
from scipy import stats

# %%
stats.mode(weights)
# Out:
# ModeResult(mode=45, count=2)

# %%
age = np.random.randint(20, 30, 10)

# %%
age
# Out:
# array([24, 29, 26, 29, 25, 20, 25, 21, 28, 22])

# %%
np.mean(age)
# Out:
# 24.9

# %%
np.median(age)
# Out:
# 25.0

# %%
import warnings as warn
warn.filterwarnings('ignore')

# %%
import pandas as pd

# %%
 pd.Series(age).mean()
# Out:
# 24.9

# %%
pd.Series(age).mode()
# Out:
# 0    25
# 1    29
# dtype: int64

# %%
pd.Series(age).median()
# Out:
# 25.0

# %%
from scipy import stats
stats.mode(age)
# Out:
# ModeResult(mode=25, count=2)
