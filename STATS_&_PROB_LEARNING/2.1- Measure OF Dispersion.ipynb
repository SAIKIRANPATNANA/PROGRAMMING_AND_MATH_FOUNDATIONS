# %% [markdown]
# ## Measure Of Dispersion

# %%
##variance
ages_lst=[23,43,23,56,74,32,68,98,45,32]

# %%
import numpy as numpy 
import pandas as pd
import seaborn as sns

# %%
np.mean(ages_lst)
# Out:
# 49.4

# %%
np.median(ages_lst)
# Out:
# 44.0

# %%
pd.Series(ages_lst).mode()
# Out:
# 0    23
# 1    32
# dtype: int64

# %%
import scipy.stats as stats
stats.mode(ages_lst)
# Out:
# ModeResult(mode=23, count=2)

# %%
np.std(ages_lst)
# Out:
# 23.273160507331188

# %%
np.var(ages_lst)
# Out:
# 541.64

# %%
mean
# Out:
# 49.4

# %%
var=np.var(ages_lst)
var
# Out:
# 541.64

# %%
std=np.std(ages_lst)
std
# Out:
# 23.273160507331188

# %%
data=[[10,12,13],[34,23,45],[32,34,21]]
data
# Out:
# [[10, 12, 13], [34, 23, 45], [32, 34, 21]]

# %%
df = pd.DataFrame({'A': [10,12,13], 'B': [34,23,45], 'C': [32,34,21]})

# %%
df=pd.DataFrame(data,columns=["A","B","C"])
df
# Out:
#     A   B   C
# 0  10  12  13
# 1  34  23  45
# 2  32  34  21

# %%
df.head()
# Out:
#     A   B   C
# 0  10  34  32
# 1  12  23  34
# 2  13  45  21

# %%
df.var()
# Out:
# A      2.333333
# B    121.000000
# C     49.000000
# dtype: float64

# %%
df.std()
# Out:
# A     1.527525
# B    11.000000
# C     7.000000
# dtype: float64

# %%
df.mean()
# Out:
# A    11.666667
# B    34.000000
# C    29.000000
# dtype: float64

# %%
df.mode()
# Out:
#     A   B   C
# 0  10  23  21
# 1  12  34  32
# 2  13  45  34

# %%
df.median()
# Out:
# A    12.0
# B    34.0
# C    32.0
# dtype: float64

# %%
df.var()
# Out:
# A    177.333333
# B    121.000000
# C    277.333333
# dtype: float64

# %%
df.var(axis = 0)
# Out:
# A      2.333333
# B    121.000000
# C     49.000000
# dtype: float64

# %%
df.var(axis = 1)
# Out:
# 0    177.333333
# 1    121.000000
# 2    277.333333
# dtype: float64

# %%
## Row wise
df.var(axis=1)
# Out:
# 0      2.333333
# 1    121.000000
# 2     49.000000
# dtype: float64

# %%
## coulmnwise
df.var(axis=0)
# Out:
# A    177.333333
# B    121.000000
# C    277.333333
# dtype: float64

# %%
len(sns.get_dataset_names())
# Out:
# 22

# %%
df = sns.load_dataset('healthexp')

# %%
df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
# df.cov()

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Spending_USD', 'Life_Expectancy'], dtype='object')

# %%
df[['Spending_USD','Life_Expectancy']].corr(method = 'pearson')
# Out:
#                  Spending_USD  Life_Expectancy
# Spending_USD          1.00000          0.57943
# Life_Expectancy       0.57943          1.00000

# %%
df[['Spending_USD','Life_Expectancy']].corr(method = 'spearman')
# Out:
#                  Spending_USD  Life_Expectancy
# Spending_USD         1.000000         0.747407
# Life_Expectancy      0.747407         1.000000

# %%
df[['Spending_USD','Life_Expectancy']].corr()
# Out:
#                  Spending_USD  Life_Expectancy
# Spending_USD          1.00000          0.57943
# Life_Expectancy       0.57943          1.00000
